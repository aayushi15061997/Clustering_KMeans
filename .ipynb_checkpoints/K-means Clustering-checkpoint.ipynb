# %%
#Clustering is similar to classification, but the basis is different. 
#In Clustering you don’t know what you are looking for, and you are trying to 
#identify some segments or clusters in your data.

# %% [raw]
# #1-choose the number of k clusters
# #2-select at random k points, the centroids(not necessarily from your dataset)
# #3- assign each data point to the closest centroid that forms k clusterds
# #4-compute and place the new centroid of each cluster(euclidean dist.)
# #5-Reassign each data point to the new closest centroid .
# #if any reassignment took place ,then go to step 4, else FINISH
# #use k-means++ to avaoid the random initialisation trap(getting undesirable
# #clusters because of a bad random initialisation)

# %%
#to choose the right number of clusters we need to minimise
#the value of metric i.e.WCCS (sum of sqaure of distnace b/w points and centroid)
#we use the elbow method(count the no. of points where change is substantial) for optimal no, of clusters
#the KMeans algorithm clusters data by trying to separate samples in n groups of equal 
#variance, minimizing a criterion known as the INERTIA or within-cluster sum-of-squares

# %%
#importing the dataset
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#importing the dataset
dataset= pd.read_csv('Mall_Customers.csv')
x = dataset.iloc[:,[3,4]].values
#Use ELBOW method to find the optimum no. of clusters
from sklearn.cluster import KMeans
#We plot our graph here to use the elbow method
wcss =[] #for 10 wccs
for i in range(1,11):
    #step1-fit kmeans to our dataset x and
    #step2- compute the within clusters sum of sqaures and appned it to the list wccs
    kmeans =KMeans(n_clusters = i,init= 'k-means++',max_iter=300,n_init=10,random_state=0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('WCSS')
plt.show()   
#Applying K-means to the mall dataset
kmeans = KMeans(n_clusters=5,init ='k-means++',max_iter =300,n_init =10,random_state=0)
#we use the fit predict method here so that k-means tells us
#in which clusters each of our customer belongs
y_kmeans =kmeans.fit_predict(x)

#visualising the clusters in 2-D
plt.scatter(x[y_kmeans==0,0],x[y_kmeans==0,1],s=100,c='red',label='Careful')
plt.scatter(x[y_kmeans==1,0],x[y_kmeans==1,1],s=100,c='blue',label='Standard')
plt.scatter(x[y_kmeans==2,0],x[y_kmeans==2,1],s=100,c='green',label='Target')
plt.scatter(x[y_kmeans==3,0],x[y_kmeans==3,1],s=100,c='cyan',label='Careless')
plt.scatter(x[y_kmeans==4,0],x[y_kmeans==4,1],s=100,c='magenta',label='Sensible')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='centroids')
plt.title('Clusters of Clients')
plt.xlabel('Annual Income(k$)')
plt.ylabel('spending score(1-100)')
plt.legend()
plt.show()
